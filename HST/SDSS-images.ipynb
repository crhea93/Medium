# %%
import pandas as pd
from astropy.io import fits
from astropy.table import Table
from astroquery.mast import Observations
from astropy import units as u
from astropy import coordinates as coords
import os
from astropy.nddata.utils import Cutout2D
import shutil
from astropy import wcs
from astropy.coordinates import SkyCoord,FK5
from astropy.wcs.utils import skycoord_to_pixel
from astroquery.sdss import SDSS
import matplotlib.pyplot as plt
import pickle
import numpy as np
from tqdm import tqdm
# Out:
# WARNING: AstropyDeprecationWarning: The update_default_config function is deprecated and may be removed in a future version. [astroquery._astropy_init]

# %%
GZ_catalog = fits.open('schawinski_GZ_2010_catalogue.fits')
catalog = Table(GZ_catalog[1].data)
# The data is stored as individual arrays where each element represents a different galaxy
# We will pull the arrays for the OBJID and Category
Redshift = catalog['REDSHIFT'][0]
ObjID = catalog['OBJID'][0]
Morphology = catalog['GZ1_MORPHOLOGY'][0]
BPT_class = catalog['BPT_CLASS'][0]
RA = catalog['RA'][0]
DEC = catalog['DEC'][0]

# %%
pix=40  # 40x40
arcsec=0.396*pix
for gal_ct in tqdm(range(len(ObjID))):#inputs[0]:
    id_ = ObjID[gal_ct]
    ra_ = RA[gal_ct]
    dec_ = DEC[gal_ct]
    # Initiate Galaxy
    pos = coords.SkyCoord(ra=ra_*u.degree, dec= dec_*u.degree, frame='fk5')
    im = SDSS.get_images)
    image_fits = im[0]
    data = image_fits[0].data
    header = image_fits[0].header
    w = wcs.WCS(image_fits[0])
    coo=SkyCoord(ra=ra_*u.degree,dec=dec_*u.degree,unit='deg',frame=FK5)
    cutout=Cutout2D(data,coo,u.Quantity((arcsec,arcsec),u.arcsec),wcs=w,mode="trim")
    #plt.imshow(np.arcsinh(cutout.data), vmin=0.5, vmax=2.5)
    #plt.colorbar()
    pickle.dump(cutout, open('../../MediumData/SDSS/'+id_+"_image.p", "wb" ))
(pos, band='r'    #plt.savefig('Example_SDSS.png')
# Out:
#   0%|          | 0/47675 [00:00<?, ?it/s]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 1/47675 [00:05<78:32:41,  5.93s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 2/47675 [00:06<38:46:52,  2.93s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 3/47675 [00:07<23:50:57,  1.80s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 4/47675 [00:07<16:50:01,  1.27s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 5/47675 [00:09<18:01:08,  1.36s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51257.000000 from DATE-OBS.
# Changed DATE-OBS from '20/03/99' to '1999-03-20''. [astropy.wcs.wcs]
#   0%|          | 6/47675 [00:10<19:57:57,  1.51s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 7/47675 [00:12<18:21:18,  1.39s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 8/47675 [00:13<17:24:31,  1.31s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 9/47675 [00:14<16:45:38,  1.27s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/1/frame-r-000752-1-0395.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 10/47675 [00:34<95:28:54,  7.21s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/3/frame-r-000752-3-0294.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 11/47675 [00:56<154:11:33, 11.65s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 12/47675 [00:57<110:27:44,  8.34s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 13/47675 [01:13<140:01:04, 10.58s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 14/47675 [01:23<137:10:01, 10.36s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 15/47675 [01:23<97:48:43,  7.39s/it] WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 16/47675 [01:28<89:48:42,  6.78s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 17/47675 [01:36<94:58:25,  7.17s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 18/47675 [01:44<94:36:17,  7.15s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/1452/3/frame-r-001452-3-0112.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 19/47675 [02:11<176:14:40, 13.31s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 20/47675 [02:32<205:16:32, 15.51s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/3/frame-r-000752-3-0472.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 21/47675 [02:52<224:22:47, 16.95s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 22/47675 [03:05<207:00:22, 15.64s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 23/47675 [03:06<148:25:13, 11.21s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 24/47675 [03:17<149:40:35, 11.31s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/
/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/5/frame-r-000752-5-0525.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/5/frame-r-000752-5-0526.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 73/47675 [12:15<174:10:54, 13.17s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 74/47675 [12:20<141:40:50, 10.72s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/1452/5/frame-r-001452-5-0073.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 75/47675 [12:33<150:48:04, 11.41s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 76/47675 [12:37<123:49:09,  9.36s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 77/47675 [12:38<88:31:07,  6.69s/it] WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/5/frame-r-000752-5-0528.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 78/47675 [12:44<86:02:54,  6.51s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 79/47675 [12:44<62:09:47,  4.70s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 80/47675 [12:45<45:22:38,  3.43s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 81/47675 [12:50<51:54:51,  3.93s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/5/frame-r-000752-5-0545.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 82/47675 [12:58<66:55:56,  5.06s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/5/frame-r-000752-5-0533.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 83/47675 [13:02<63:16:29,  4.79s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 84/47675 [13:02<46:07:32,  3.49s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# ...
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 160/47675 [29:26<193:14:41, 14.64s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/1477/2/frame-r-001477-2-0063.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51257.000000 from DATE-OBS.
# Changed DATE-OBS from '20/03/99' to '1999-03-20''. [astropy.wcs.wcs]
#   0%|          | 161/47675 [29:59<263:08:53, 19.94s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/3/frame-r-000752-3-0334.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 162/47675 [30:09<226:48:32, 17.19s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/3/frame-r-000752-3-0217.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/2141/3/frame-r-002141-3-0224.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 163/47675 [30:44<293:47:50, 22.26s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/3/frame-r-000752-3-0276.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 164/47675 [31:08<301:15:21, 22.83s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 165/47675 [31:24<276:40:02, 20.96s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/2029/3/frame-r-002029-3-0252.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 166/47675 [31:48<288:42:32, 21.88s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 167/47675 [31:59<246:08:43, 18.65s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 168/47675 [32:09<211:22:56, 16.02s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 169/47675 [32:26<212:54:44, 16.13s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 170/47675 [32:33<179:25:29, 13.60s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/3/frame-r-000752-3-0344.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 171/47675 [32:37<141:40:27, 10.74s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 172/47675 [32:44<125:16:04,  9.49s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 173/47675 [32:50<111:13:05,  8.43s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/3/frame-r-000752-3-0375.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 174/47675 [32:59<114:06:28,  8.65s/it]WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / International Celestial Ref. System
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 51258.000000 from DATE-OBS.
# Changed DATE-OBS from '21/03/99' to '1999-03-21''. [astropy.wcs.wcs]
#   0%|          | 175/47675 [33:17<149:49:09, 11.35s/it]WARNING: Verification of TLS/SSL certificate at https://data.sdss.org/sas/dr14/eboss/photoObj/frames/301/752/3/frame-r-000752-3-0530.fits.bz2 failed: this can mean either the server is misconfigured or your local root CA certificates are out-of-date; in the latter case this can usually be addressed by installing the Python package "certifi" (see the documentation for astropy.utils.data.download_url). Re-trying with allow_insecure=True. [astropy.utils.data]
#   0%|          | 175/47675 [33:21<150:53:32, 11.44s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <module>
#       7 # Initiate Galaxy
#       8 pos = coords.SkyCoord(ra=ra_*u.degree, dec= dec_*u.degree, frame='fk5')
# ----> 9 im = SDSS.get_images(pos, band='r')
#      10 image_fits = im[0]
#      11 data = image_fits[0].data
#
# File ~/miniconda3/envs/astro/lib/python3.9/site-packages/astroquery/sdss/core.py:774, in SDSSClass.get_images(self, coordinates, radius, matches, run, rerun, camcol, field, band, timeout, cache, get_query_payload, data_release, show_progress)
#     772     return readable_objs
#     773 else:
# --> 774     return [obj.get_fits() for obj in readable_objs]
#
# File ~/miniconda3/envs/astro/lib/python3.9/site-packages/astroquery/sdss/core.py:774, in <listcomp>(.0)
#     772     return readable_objs
#     773 else:
# --> 774     return [obj.get_fits() for obj in readable_objs]
#
# File ~/miniconda3/envs/astro/lib/python3.9/site-packages/astroquery/utils/commons.py:365, in FileContainer.get_fits(self)
#     360 def get_fits(self):
#     361     """
#     362     Assuming the contained file is a FITS file, read it
#     363     and return the file parsed as FITS HDUList
#     364     """
# --> 365     filedata = self.get_string()
#     367     if len(filedata) == 0:
#     368         raise TypeError("The file retrieved was empty.")
#
# File ~/miniconda3/envs/astro/lib/python3.9/site-packages/astroquery/utils/commons.py:424, in FileContainer.get_string(self)
#     422 if not hasattr(self, '_string'):
#     423     try:
# --> 424         with self._readable_object as f:
#     425             data = f.read()
#     426             self._string = data
#
# File ~/miniconda3/envs/astro/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/astro/lib/python3.9/site-packages/astropy/utils/data.py:268, in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers)
#     266 is_url = _is_url(name_or_obj)
#     267 if is_url:
# --> 268     name_or_obj = download_file(
#     269         name_or_obj, cache=cache, show_progress=show_progress,
#     270         timeout=remote_timeout, sources=sources,
#     271         http_headers=http_headers)
#     272 fileobj = io.FileIO(name_or_obj, 'r')
#     273 if is_url and not cache:
#
# File ~/miniconda3/envs/astro/lib/python3.9/site-packages/astropy/utils/data.py:1364, in download_file(remote_url, cache, show_progress, timeout, sources, pkgname, http_headers, ssl_context, allow_insecure)
#    1362 for source_url in sources:
#    1363     try:
# -> 1364         f_name = _download_file_from_source(
#    1365                 source_url,
#    1366                 timeout=timeout,
#    1367                 show_progress=show_progress,
#    1368                 cache=cache,
#    1369                 remote_url=remote_url,
#    1370                 pkgname=pkgname,
#    1371                 http_headers=http_headers,
#    1372                 ssl_context=ssl_context,
#    1373                 allow_insecure=allow_insecure)
#    1374         # Success!
#    1375         break
#
# File ~/miniconda3/envs/astro/lib/python3.9/site-packages/astropy/utils/data.py:1202, in _download_file_from_source(source_url, show_progress, timeout, remote_url, cache, pkgname, http_headers, ftp_tls, ssl_context, allow_insecure)
#    1200 bytes_read += len(block)
#    1201 p.update(bytes_read)
# -> 1202 block = remote.read(conf.download_block_size)
#    1203 if size is not None and bytes_read > size:
#    1204     raise urllib.error.URLError(
#    1205         f"File was supposed to be {size} bytes but "
#    1206         f"server provides more, at least {bytes_read} "
#    1207         f"bytes. Download failed.")
#
# File ~/miniconda3/envs/astro/lib/python3.9/http/client.py:462, in HTTPResponse.read(self, amt)
#     459 if amt is not None:
#     460     # Amount is given, implement using readinto
#     461     b = bytearray(amt)
# --> 462     n = self.readinto(b)
#     463     return memoryview(b)[:n].tobytes()
#     464 else:
#     465     # Amount is not given (unbounded read) so we must check self.length
#     466     # and self.chunked
#
# File ~/miniconda3/envs/astro/lib/python3.9/http/client.py:506, in HTTPResponse.readinto(self, b)
#     501         b = memoryview(b)[0:self.length]
#     503 # we do not use _safe_read() here because this may be a .will_close
#     504 # connection, and the user is reading more bytes than will be provided
#     505 # (for example, reading in 1k chunks)
# --> 506 n = self.fp.readinto(b)
#     507 if not n and b:
#     508     # Ideally, we would raise IncompleteRead if the content-length
#     509     # wasn't satisfied, but it might break compatibility.
#     510     self._close_conn()
#
# File ~/miniconda3/envs/astro/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/miniconda3/envs/astro/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/astro/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:
